# %%
import pandas as pd

# %%
df = pd.DataFrame({'FER2013' : [0.5773, 0.59854, 0.74651, 0.64366, 0.74585, 0.774, 0.59754, 0.59754],
              'FER+' : [0.602, 0.627, 0.784, 0.671, 0.763, 0.806, 0.6770, 0.6770],
              'CK+' : [0.6551, 0.75862, 1, 1, 1, 1, 0.72881, 1],},
             index=['BernoulliNB', 'GaussianNB', 'SVM', 'DecisionTree', 'RandomForest',
                    'XGBoost', 'VGG19(CNN)', 'VGG16(CNN)'])

# %%
df
# Out:
#               FER2013   FER+      CK+
# BernoulliNB   0.57730  0.602  0.65510
# GaussianNB    0.59854  0.627  0.75862
# SVM           0.74651  0.784  1.00000
# DecisionTree  0.64366  0.671  1.00000
# RandomForest  0.74585  0.763  1.00000
# XGBoost       0.77400  0.806  1.00000
# VGG19(CNN)    0.59754  0.677  0.72881
# VGG16(CNN)    0.59754  0.677  1.00000

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.figure(figsize=(4,5))
ax = sns.heatmap(df, annot=True, cmap="YlGnBu", fmt='.3f')
ax.xaxis.tick_top()
plt.show()
