# %% [markdown]
# # 2. FERPlus VGG16 분류

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import xgboost as xgb
import tensorflow as tf
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC

from sklearn.model_selection import train_test_split

import keras.backend.tensorflow_backend as K
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Flatten, Dropout, concatenate, Add, Input, Conv2D, BatchNormalization, MaxPooling2D, GlobalMaxPooling2D, AveragePooling2D
from keras.optimizers import Adam, Adadelta
from keras.regularizers import l2
from keras.layers.advanced_activations import LeakyReLU
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint

from keras.applications.vgg19 import VGG19
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 2.1. 학습에 사용될 하이퍼 패러미터 선언 및 Random Seed 설정

# %%
np.random.seed(201)

# %%
FERPLUS_DIR = "datasets/ferPlus/prep/"
INPUT_TRAIN_DATA = 'ferPlus_X.npy'
LABEL_TRAIN_DATA = 'ferPlus_y.npy'

TEST_SPLIT = 0.2
RND_SEED = 0

# %%
input_data = np.load(open(FERPLUS_DIR + INPUT_TRAIN_DATA, 'rb'))
label_data = np.load(open(FERPLUS_DIR + LABEL_TRAIN_DATA, 'rb'))

# %%
input_data = np.squeeze(input_data)
input_data = np.stack((input_data,)*3, axis=3)

# %%
input_shape = input_data[1].shape
print('Input Shape is :', input_shape)
# Out:
# Input Shape is : (48, 48, 3)

# %%
x_train, x_test, y_train, y_test = train_test_split(input_data,
                                                    label_data,
                                                    test_size=TEST_SPLIT,
                                                    random_state=RND_SEED)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train,
                                                  y_train,
                                                  test_size=TEST_SPLIT,
                                                  random_state=RND_SEED)

# %%
print(x_train.shape)
print(x_val.shape)
print(x_test.shape)
# Out:
# (8784, 48, 48, 3)
# (2196, 48, 48, 3)
# (2746, 48, 48, 3)

# %% [markdown]
# ## 2.2 CNN모델 정의

# %% [markdown]
# 모델 컴파일

# %%
base_model = VGG16(weights=None, include_top=False, input_shape=(48, 48, 3))

# %%
x = base_model.output
x = Flatten()(x)
predictions = Dense(2, activation='softmax')(x)

# %%
model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.summary()
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 48, 48, 3)         0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 48, 48, 64)        1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 48, 48, 64)        36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 24, 24, 64)        0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 24, 24, 128)       73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 24, 24, 128)       147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 12, 12, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 12, 12, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 12, 12, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 12, 12, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 6, 6, 256)         0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 6, 6, 512)         1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 6, 6, 512)         2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 3, 3, 512)         0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 3, 3, 512)         2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 1, 1, 512)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 1026
# =================================================================
# Total params: 14,715,714
# Trainable params: 14,715,714
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 모델 플롯 생성

# %%
tf.keras.utils.plot_model(model, show_shapes=True)

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
MODEL_PATH = 'weights.h5f'

# %%
check_point = ModelCheckpoint(filepath=MODEL_PATH, monitor='val_accuracy', verbose=1, save_best_only=True)

# %% [markdown]
# ## 2.3 CNN 모델 훈련

# %%
batch_size = 32
epochs = 100

# %%
# Training
with K.tf_ops.device('/device:GPU:0'):
    history = model.fit(x_train, y_train, epochs = epochs, batch_size = batch_size,
                        validation_data = (x_val, y_val), callbacks=[check_point])
# Out:
# Train on 8784 samples, validate on 2196 samples
# Epoch 1/100
# 8784/8784 [==============================] - 9s 971us/step - loss: 0.6456 - accuracy: 0.6791 - val_loss: 0.6217 - val_accuracy: 0.6972
#
# Epoch 00001: val_accuracy improved from -inf to 0.69718, saving model to weights.h5f
# Epoch 2/100
# 8784/8784 [==============================] - 6s 736us/step - loss: 0.6289 - accuracy: 0.6791 - val_loss: 0.6163 - val_accuracy: 0.6972
#
# Epoch 00002: val_accuracy did not improve from 0.69718
# Epoch 3/100
# 8784/8784 [==============================] - 6s 728us/step - loss: 0.6285 - accuracy: 0.6791 - val_loss: 0.6162 - val_accuracy: 0.6972
#
# Epoch 00003: val_accuracy did not improve from 0.69718
# Epoch 4/100
# 8784/8784 [==============================] - 6s 739us/step - loss: 0.6283 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00004: val_accuracy did not improve from 0.69718
# Epoch 5/100
# 8784/8784 [==============================] - 7s 747us/step - loss: 0.6284 - accuracy: 0.6791 - val_loss: 0.6137 - val_accuracy: 0.6972
#
# Epoch 00005: val_accuracy did not improve from 0.69718
# Epoch 6/100
# 8784/8784 [==============================] - 7s 747us/step - loss: 0.6281 - accuracy: 0.6791 - val_loss: 0.6143 - val_accuracy: 0.6972
#
# Epoch 00006: val_accuracy did not improve from 0.69718
# Epoch 7/100
# 8784/8784 [==============================] - 6s 737us/step - loss: 0.6284 - accuracy: 0.6791 - val_loss: 0.6143 - val_accuracy: 0.6972
#
# Epoch 00007: val_accuracy did not improve from 0.69718
# Epoch 8/100
# 8784/8784 [==============================] - 6s 735us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6134 - val_accuracy: 0.6972
#
# Epoch 00008: val_accuracy did not improve from 0.69718
# Epoch 9/100
# 8784/8784 [==============================] - 6s 735us/step - loss: 0.6285 - accuracy: 0.6791 - val_loss: 0.6134 - val_accuracy: 0.6972
#
# Epoch 00009: val_accuracy did not improve from 0.69718
# Epoch 10/100
# 8784/8784 [==============================] - 7s 742us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6178 - val_accuracy: 0.6972
#
# Epoch 00010: val_accuracy did not improve from 0.69718
# Epoch 11/100
# 8784/8784 [==============================] - 6s 729us/step - loss: 0.6284 - accuracy: 0.6791 - val_loss: 0.6136 - val_accuracy: 0.6972
#
# Epoch 00011: val_accuracy did not improve from 0.69718
# Epoch 12/100
# 8784/8784 [==============================] - 7s 750us/step - loss: 0.6283 - accuracy: 0.6791 - val_loss: 0.6151 - val_accuracy: 0.6972
#
# Epoch 00012: val_accuracy did not improve from 0.69718
# Epoch 13/100
# 8784/8784 [==============================] - 7s 782us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6140 - val_accuracy: 0.6972
#
# Epoch 00013: val_accuracy did not improve from 0.69718
# Epoch 14/100
# 8784/8784 [==============================] - 6s 727us/step - loss: 0.6282 - accuracy: 0.6791 - val_loss: 0.6165 - val_accuracy: 0.6972
#
# Epoch 00014: val_accuracy did not improve from 0.69718
# Epoch 15/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6134 - val_accuracy: 0.6972
#
# Epoch 00015: val_accuracy did not improve from 0.69718
# Epoch 16/100
# 8784/8784 [==============================] - 6s 728us/step - loss: 0.6282 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00016: val_accuracy did not improve from 0.69718
# Epoch 17/100
# 8784/8784 [==============================] - 7s 748us/step - loss: 0.6283 - accuracy: 0.6791 - val_loss: 0.6141 - val_accuracy: 0.6972
#
# Epoch 00017: val_accuracy did not improve from 0.69718
# Epoch 18/100
# 8784/8784 [==============================] - 6s 739us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6142 - val_accuracy: 0.6972
#
# Epoch 00018: val_accuracy did not improve from 0.69718
# Epoch 19/100
# 8784/8784 [==============================] - 6s 728us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6132 - val_accuracy: 0.6972
#
# Epoch 00019: val_accuracy did not improve from 0.69718
# Epoch 20/100
# 8784/8784 [==============================] - 6s 732us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6132 - val_accuracy: 0.6972
#
# Epoch 00020: val_accuracy did not improve from 0.69718
# Epoch 21/100
# 8784/8784 [==============================] - 6s 732us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6137 - val_accuracy: 0.6972
#
# Epoch 00021: val_accuracy did not improve from 0.69718
# Epoch 22/100
# 8784/8784 [==============================] - 6s 736us/step - loss: 0.6281 - accuracy: 0.6791 - val_loss: 0.6140 - val_accuracy: 0.6972
#
# Epoch 00022: val_accuracy did not improve from 0.69718
# Epoch 23/100
# 8784/8784 [==============================] - 6s 734us/step - loss: 0.6282 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00023: val_accuracy did not improve from 0.69718
# Epoch 24/100
# 8784/8784 [==============================] - 6s 739us/step - loss: 0.6281 - accuracy: 0.6791 - val_loss: 0.6134 - val_accuracy: 0.6972
#
# Epoch 00024: val_accuracy did not improve from 0.69718
# Epoch 25/100
# 8784/8784 [==============================] - 6s 739us/step - loss: 0.6281 - accuracy: 0.6791 - val_loss: 0.6139 - val_accuracy: 0.6972
#
# Epoch 00025: val_accuracy did not improve from 0.69718
# Epoch 26/100
# 8784/8784 [==============================] - 7s 747us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6139 - val_accuracy: 0.6972
#
# Epoch 00026: val_accuracy did not improve from 0.69718
# Epoch 27/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6151 - val_accuracy: 0.6972
#
# Epoch 00027: val_accuracy did not improve from 0.69718
# Epoch 28/100
# 8784/8784 [==============================] - 6s 709us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6147 - val_accuracy: 0.6972
#
# Epoch 00028: val_accuracy did not improve from 0.69718
# Epoch 29/100
# 8784/8784 [==============================] - 7s 742us/step - loss: 0.6282 - accuracy: 0.6791 - val_loss: 0.6153 - val_accuracy: 0.6972
#
# Epoch 00029: val_accuracy did not improve from 0.69718
# Epoch 30/100
# 8784/8784 [==============================] - 6s 732us/step - loss: 0.6282 - accuracy: 0.6791 - val_loss: 0.6171 - val_accuracy: 0.6972
#
# Epoch 00030: val_accuracy did not improve from 0.69718
# Epoch 31/100
# 8784/8784 [==============================] - 6s 734us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6138 - val_accuracy: 0.6972
#
# Epoch 00031: val_accuracy did not improve from 0.69718
# Epoch 32/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00032: val_accuracy did not improve from 0.69718
# Epoch 33/100
# 8784/8784 [==============================] - 6s 739us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00033: val_accuracy did not improve from 0.69718
# Epoch 34/100
# 8784/8784 [==============================] - 7s 752us/step - loss: 0.6282 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00034: val_accuracy did not improve from 0.69718
# Epoch 35/100
# 8784/8784 [==============================] - 6s 729us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6132 - val_accuracy: 0.6972
#
# Epoch 00035: val_accuracy did not improve from 0.69718
# Epoch 36/100
# 8784/8784 [==============================] - 7s 742us/step - loss: 0.6283 - accuracy: 0.6791 - val_loss: 0.6138 - val_accuracy: 0.6972
#
# Epoch 00036: val_accuracy did not improve from 0.69718
# Epoch 37/100
# 8784/8784 [==============================] - 7s 747us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6158 - val_accuracy: 0.6972
#
# Epoch 00037: val_accuracy did not improve from 0.69718
# Epoch 38/100
# 8784/8784 [==============================] - 7s 741us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00038: val_accuracy did not improve from 0.69718
# Epoch 39/100
# 8784/8784 [==============================] - 7s 745us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6146 - val_accuracy: 0.6972
#
# Epoch 00039: val_accuracy did not improve from 0.69718
# Epoch 40/100
# 8784/8784 [==============================] - 7s 745us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6132 - val_accuracy: 0.6972
#
# Epoch 00040: val_accuracy did not improve from 0.69718
# Epoch 41/100
# 8784/8784 [==============================] - 6s 736us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00041: val_accuracy did not improve from 0.69718
# Epoch 42/100
# 8784/8784 [==============================] - 7s 742us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00042: val_accuracy did not improve from 0.69718
# Epoch 43/100
# 8784/8784 [==============================] - 7s 752us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6145 - val_accuracy: 0.6972
#
# Epoch 00043: val_accuracy did not improve from 0.69718
# Epoch 44/100
# 8784/8784 [==============================] - 6s 731us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6143 - val_accuracy: 0.6972
#
# Epoch 00044: val_accuracy did not improve from 0.69718
# Epoch 45/100
# 8784/8784 [==============================] - 6s 729us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6144 - val_accuracy: 0.6972
#
# Epoch 00045: val_accuracy did not improve from 0.69718
# Epoch 46/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00046: val_accuracy did not improve from 0.69718
# Epoch 47/100
# 8784/8784 [==============================] - 6s 735us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6144 - val_accuracy: 0.6972
#
# Epoch 00047: val_accuracy did not improve from 0.69718
# Epoch 48/100
# 8784/8784 [==============================] - 7s 742us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6135 - val_accuracy: 0.6972
#
# Epoch 00048: val_accuracy did not improve from 0.69718
# Epoch 49/100
# 8784/8784 [==============================] - 7s 744us/step - loss: 0.6281 - accuracy: 0.6791 - val_loss: 0.6143 - val_accuracy: 0.6972
#
# Epoch 00049: val_accuracy did not improve from 0.69718
# Epoch 50/100
# 8784/8784 [==============================] - 7s 745us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6144 - val_accuracy: 0.6972
#
# Epoch 00050: val_accuracy did not improve from 0.69718
# Epoch 51/100
# 8784/8784 [==============================] - 6s 739us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6145 - val_accuracy: 0.6972
#
# Epoch 00051: val_accuracy did not improve from 0.69718
# Epoch 52/100
# 8784/8784 [==============================] - 6s 735us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6136 - val_accuracy: 0.6972
#
# Epoch 00052: val_accuracy did not improve from 0.69718
# Epoch 53/100
# 8784/8784 [==============================] - 6s 730us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6157 - val_accuracy: 0.6972
#
# Epoch 00053: val_accuracy did not improve from 0.69718
# Epoch 54/100
# 8784/8784 [==============================] - 6s 732us/step - loss: 0.6281 - accuracy: 0.6791 - val_loss: 0.6142 - val_accuracy: 0.6972
#
# Epoch 00054: val_accuracy did not improve from 0.69718
# Epoch 55/100
# 8784/8784 [==============================] - 6s 718us/step - loss: 0.6275 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00055: val_accuracy did not improve from 0.69718
# Epoch 56/100
# 8784/8784 [==============================] - 6s 728us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6136 - val_accuracy: 0.6972
#
# Epoch 00056: val_accuracy did not improve from 0.69718
# Epoch 57/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6139 - val_accuracy: 0.6972
#
# Epoch 00057: val_accuracy did not improve from 0.69718
# Epoch 58/100
# 8784/8784 [==============================] - 7s 741us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6142 - val_accuracy: 0.6972
#
# Epoch 00058: val_accuracy did not improve from 0.69718
# Epoch 59/100
# 8784/8784 [==============================] - 6s 720us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6148 - val_accuracy: 0.6972
#
# Epoch 00059: val_accuracy did not improve from 0.69718
# Epoch 60/100
# 8784/8784 [==============================] - 6s 730us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6135 - val_accuracy: 0.6972
#
# Epoch 00060: val_accuracy did not improve from 0.69718
# Epoch 61/100
# 8784/8784 [==============================] - 6s 732us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6144 - val_accuracy: 0.6972
#
# Epoch 00061: val_accuracy did not improve from 0.69718
# Epoch 62/100
# 8784/8784 [==============================] - 6s 737us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6134 - val_accuracy: 0.6972
#
# Epoch 00062: val_accuracy did not improve from 0.69718
# Epoch 63/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6281 - accuracy: 0.6791 - val_loss: 0.6140 - val_accuracy: 0.6972
#
# Epoch 00063: val_accuracy did not improve from 0.69718
# Epoch 64/100
# 8784/8784 [==============================] - 7s 745us/step - loss: 0.6277 - accuracy: 0.6791 - val_loss: 0.6135 - val_accuracy: 0.6972
#
# Epoch 00064: val_accuracy did not improve from 0.69718
# Epoch 65/100
# 8784/8784 [==============================] - 6s 730us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6140 - val_accuracy: 0.6972
#
# Epoch 00065: val_accuracy did not improve from 0.69718
# Epoch 66/100
# 8784/8784 [==============================] - 7s 744us/step - loss: 0.6276 - accuracy: 0.6791 - val_loss: 0.6135 - val_accuracy: 0.6972
#
# Epoch 00066: val_accuracy did not improve from 0.69718
# Epoch 67/100
# 8784/8784 [==============================] - 7s 747us/step - loss: 0.6277 - accuracy: 0.6791 - val_loss: 0.6165 - val_accuracy: 0.6972
#
# Epoch 00067: val_accuracy did not improve from 0.69718
# Epoch 68/100
# 8784/8784 [==============================] - 7s 742us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6158 - val_accuracy: 0.6972
#
# Epoch 00068: val_accuracy did not improve from 0.69718
# Epoch 69/100
# 8784/8784 [==============================] - 7s 748us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6138 - val_accuracy: 0.6972
#
# Epoch 00069: val_accuracy did not improve from 0.69718
# Epoch 70/100
# 8784/8784 [==============================] - 6s 736us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6141 - val_accuracy: 0.6972
#
# Epoch 00070: val_accuracy did not improve from 0.69718
# Epoch 71/100
# 8784/8784 [==============================] - 7s 777us/step - loss: 0.6276 - accuracy: 0.6791 - val_loss: 0.6132 - val_accuracy: 0.6972
#
# Epoch 00071: val_accuracy did not improve from 0.69718
# Epoch 72/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6277 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00072: val_accuracy did not improve from 0.69718
# Epoch 73/100
# 8784/8784 [==============================] - 6s 732us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6146 - val_accuracy: 0.6972
#
# Epoch 00073: val_accuracy did not improve from 0.69718
# Epoch 74/100
# 8784/8784 [==============================] - 6s 738us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6142 - val_accuracy: 0.6972
#
# Epoch 00074: val_accuracy did not improve from 0.69718
# Epoch 75/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6277 - accuracy: 0.6791 - val_loss: 0.6136 - val_accuracy: 0.6972
#
# Epoch 00075: val_accuracy did not improve from 0.69718
# Epoch 76/100
# 8784/8784 [==============================] - 7s 748us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00076: val_accuracy did not improve from 0.69718
# Epoch 77/100
# 8784/8784 [==============================] - 6s 728us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6135 - val_accuracy: 0.6972
#
# Epoch 00077: val_accuracy did not improve from 0.69718
# Epoch 78/100
# 8784/8784 [==============================] - 6s 736us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6134 - val_accuracy: 0.6972
#
# Epoch 00078: val_accuracy did not improve from 0.69718
# Epoch 79/100
# 8784/8784 [==============================] - 6s 734us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6140 - val_accuracy: 0.6972
#
# Epoch 00079: val_accuracy did not improve from 0.69718
# Epoch 80/100
# 8784/8784 [==============================] - 6s 731us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00080: val_accuracy did not improve from 0.69718
# Epoch 81/100
# 8784/8784 [==============================] - 7s 748us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6134 - val_accuracy: 0.6972
#
# Epoch 00081: val_accuracy did not improve from 0.69718
# Epoch 82/100
# 8784/8784 [==============================] - 7s 746us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6139 - val_accuracy: 0.6972
#
# Epoch 00082: val_accuracy did not improve from 0.69718
# Epoch 83/100
# 8784/8784 [==============================] - 6s 737us/step - loss: 0.6276 - accuracy: 0.6791 - val_loss: 0.6133 - val_accuracy: 0.6972
#
# Epoch 00083: val_accuracy did not improve from 0.69718
# Epoch 84/100
# 8784/8784 [==============================] - 6s 739us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6147 - val_accuracy: 0.6972
#
# Epoch 00084: val_accuracy did not improve from 0.69718
# Epoch 85/100
# 8784/8784 [==============================] - 7s 745us/step - loss: 0.6277 - accuracy: 0.6791 - val_loss: 0.6141 - val_accuracy: 0.6972
#
# Epoch 00085: val_accuracy did not improve from 0.69718
# Epoch 86/100
# 8784/8784 [==============================] - 6s 739us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6138 - val_accuracy: 0.6972
#
# Epoch 00086: val_accuracy did not improve from 0.69718
# Epoch 87/100
# 8784/8784 [==============================] - 7s 748us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6142 - val_accuracy: 0.6972
#
# Epoch 00087: val_accuracy did not improve from 0.69718
# Epoch 88/100
# 8784/8784 [==============================] - 7s 740us/step - loss: 0.6277 - accuracy: 0.6791 - val_loss: 0.6154 - val_accuracy: 0.6972
#
# Epoch 00088: val_accuracy did not improve from 0.69718
# Epoch 89/100
# 8784/8784 [==============================] - 7s 743us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6139 - val_accuracy: 0.6972
#
# Epoch 00089: val_accuracy did not improve from 0.69718
# Epoch 90/100
# 8784/8784 [==============================] - 6s 735us/step - loss: 0.6279 - accuracy: 0.6791 - val_loss: 0.6149 - val_accuracy: 0.6972
#
# Epoch 00090: val_accuracy did not improve from 0.69718
# Epoch 91/100
# 8784/8784 [==============================] - 7s 766us/step - loss: 0.6280 - accuracy: 0.6791 - val_loss: 0.6146 - val_accuracy: 0.6972
#
# Epoch 00091: val_accuracy did not improve from 0.69718
# Epoch 92/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6150 - val_accuracy: 0.6972
#
# Epoch 00092: val_accuracy did not improve from 0.69718
# Epoch 93/100
# 8784/8784 [==============================] - 6s 729us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6149 - val_accuracy: 0.6972
#
# Epoch 00093: val_accuracy did not improve from 0.69718
# Epoch 94/100
# 8784/8784 [==============================] - 6s 733us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6140 - val_accuracy: 0.6972
#
# Epoch 00094: val_accuracy did not improve from 0.69718
# Epoch 95/100
# 8784/8784 [==============================] - 6s 734us/step - loss: 0.6277 - accuracy: 0.6791 - val_loss: 0.6137 - val_accuracy: 0.6972
#
# Epoch 00095: val_accuracy did not improve from 0.69718
# Epoch 96/100
# 8784/8784 [==============================] - 7s 744us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6151 - val_accuracy: 0.6972
#
# Epoch 00096: val_accuracy did not improve from 0.69718
# Epoch 97/100
# 8784/8784 [==============================] - 7s 746us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6135 - val_accuracy: 0.6972
#
# Epoch 00097: val_accuracy did not improve from 0.69718
# Epoch 98/100
# 8784/8784 [==============================] - 6s 732us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6139 - val_accuracy: 0.6972
#
# Epoch 00098: val_accuracy did not improve from 0.69718
# Epoch 99/100
# 8784/8784 [==============================] - 7s 744us/step - loss: 0.6278 - accuracy: 0.6791 - val_loss: 0.6137 - val_accuracy: 0.6972
#
# Epoch 00099: val_accuracy did not improve from 0.69718
# Epoch 100/100
# 8784/8784 [==============================] - 7s 748us/step - loss: 0.6276 - accuracy: 0.6791 - val_loss: 0.6145 - val_accuracy: 0.6972
#
# Epoch 00100: val_accuracy did not improve from 0.69718

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training for ' +str(epochs)+ ' epochs')
plt.legend(['Training accuracy', 'Validation accuracy'], loc='lower right')
plt.show()

# %% [markdown]
# 검증셋 정확도

# %%
model.load_weights(MODEL_PATH)
results = model.evaluate(x_val, y_val)
print('Test accuracy: ', results[1])
# Out:
# 2196/2196 [==============================] - 1s 313us/step
# Test accuracy:  0.6971766948699951

# %% [markdown]
# 테스트셋 정확도

# %%
results = model.evaluate(x_test, y_test)
print('Test accuracy: ', results[1])
# Out:
# 2746/2746 [==============================] - 1s 381us/step
# Test accuracy:  0.6769847273826599

# %% [markdown]
# ## 1.3 K-fold  Cross Validation 이용

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy', metrics=['accuracy'])

# %%
from sklearn.model_selection import KFold

kf = KFold(n_splits=10, random_state=RND_SEED, shuffle=True)

for train_index, test_index in kf.split(input_data):
    X_train, X_test = input_data[train_index], input_data[test_index]
    Y_train, Y_test = label_data[train_index], label_data[test_index]

# %%
with K.tf_ops.device('/device:GPU:0'):
    history = model.fit(X_train, Y_train, epochs = epochs, batch_size = batch_size,
                        validation_data = (X_test, Y_test), callbacks=[check_point])
# Out:
# Train on 12354 samples, validate on 1372 samples
# Epoch 1/100
# 12354/12354 [==============================] - 9s 749us/step - loss: 0.6265 - accuracy: 0.6821 - val_loss: 0.6299 - val_accuracy: 0.6764
#
# Epoch 00001: val_accuracy did not improve from 0.69718
# Epoch 2/100
# 12354/12354 [==============================] - 8s 682us/step - loss: 0.6263 - accuracy: 0.6821 - val_loss: 0.6302 - val_accuracy: 0.6764
#
# Epoch 00002: val_accuracy did not improve from 0.69718
# Epoch 3/100
# 12354/12354 [==============================] - 9s 692us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6310 - val_accuracy: 0.6764
#
# Epoch 00003: val_accuracy did not improve from 0.69718
# Epoch 4/100
# 12354/12354 [==============================] - 9s 689us/step - loss: 0.6264 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00004: val_accuracy did not improve from 0.69718
# Epoch 5/100
# 12354/12354 [==============================] - 9s 711us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00005: val_accuracy did not improve from 0.69718
# Epoch 6/100
# 12354/12354 [==============================] - 9s 691us/step - loss: 0.6258 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00006: val_accuracy did not improve from 0.69718
# Epoch 7/100
# 12354/12354 [==============================] - 9s 692us/step - loss: 0.6258 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00007: val_accuracy did not improve from 0.69718
# Epoch 8/100
# 12354/12354 [==============================] - 9s 688us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6299 - val_accuracy: 0.6764
#
# Epoch 00008: val_accuracy did not improve from 0.69718
# Epoch 9/100
# 12354/12354 [==============================] - 9s 718us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00009: val_accuracy did not improve from 0.69718
# Epoch 10/100
# 12354/12354 [==============================] - 8s 686us/step - loss: 0.6259 - accuracy: 0.6821 - val_loss: 0.6309 - val_accuracy: 0.6764
#
# Epoch 00010: val_accuracy did not improve from 0.69718
# Epoch 11/100
# 12354/12354 [==============================] - 9s 695us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6299 - val_accuracy: 0.6764
#
# Epoch 00011: val_accuracy did not improve from 0.69718
# Epoch 12/100
# 12354/12354 [==============================] - 8s 687us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00012: val_accuracy did not improve from 0.69718
# Epoch 13/100
# 12354/12354 [==============================] - 9s 689us/step - loss: 0.6260 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00013: val_accuracy did not improve from 0.69718
# Epoch 14/100
# 12354/12354 [==============================] - 9s 695us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6304 - val_accuracy: 0.6764
#
# Epoch 00014: val_accuracy did not improve from 0.69718
# Epoch 15/100
# 12354/12354 [==============================] - 9s 708us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6299 - val_accuracy: 0.6764
#
# Epoch 00015: val_accuracy did not improve from 0.69718
# Epoch 16/100
# 12354/12354 [==============================] - 9s 692us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6301 - val_accuracy: 0.6764
#
# Epoch 00016: val_accuracy did not improve from 0.69718
# Epoch 17/100
# 12354/12354 [==============================] - 9s 691us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00017: val_accuracy did not improve from 0.69718
# Epoch 18/100
# 12354/12354 [==============================] - 9s 701us/step - loss: 0.6260 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00018: val_accuracy did not improve from 0.69718
# Epoch 19/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00019: val_accuracy did not improve from 0.69718
# Epoch 20/100
# 12354/12354 [==============================] - 9s 698us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6317 - val_accuracy: 0.6764
#
# Epoch 00020: val_accuracy did not improve from 0.69718
# Epoch 21/100
# 12354/12354 [==============================] - 9s 694us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6300 - val_accuracy: 0.6764
#
# Epoch 00021: val_accuracy did not improve from 0.69718
# Epoch 22/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6299 - val_accuracy: 0.6764
#
# Epoch 00022: val_accuracy did not improve from 0.69718
# Epoch 23/100
# 12354/12354 [==============================] - 9s 697us/step - loss: 0.6259 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00023: val_accuracy did not improve from 0.69718
# Epoch 24/100
# 12354/12354 [==============================] - 9s 696us/step - loss: 0.6259 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00024: val_accuracy did not improve from 0.69718
# Epoch 25/100
# 12354/12354 [==============================] - 9s 691us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00025: val_accuracy did not improve from 0.69718
# Epoch 26/100
# 12354/12354 [==============================] - 9s 735us/step - loss: 0.6260 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00026: val_accuracy did not improve from 0.69718
# Epoch 27/100
# 12354/12354 [==============================] - 9s 699us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00027: val_accuracy did not improve from 0.69718
# Epoch 28/100
# 12354/12354 [==============================] - 9s 709us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00028: val_accuracy did not improve from 0.69718
# Epoch 29/100
# 12354/12354 [==============================] - 9s 698us/step - loss: 0.6258 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00029: val_accuracy did not improve from 0.69718
# Epoch 30/100
# 12354/12354 [==============================] - 9s 700us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00030: val_accuracy did not improve from 0.69718
# Epoch 31/100
# 12354/12354 [==============================] - 9s 710us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6319 - val_accuracy: 0.6764
#
# Epoch 00031: val_accuracy did not improve from 0.69718
# Epoch 32/100
# 12354/12354 [==============================] - 9s 718us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00032: val_accuracy did not improve from 0.69718
# Epoch 33/100
# 12354/12354 [==============================] - 9s 692us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00033: val_accuracy did not improve from 0.69718
# Epoch 34/100
# 12354/12354 [==============================] - 9s 702us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00034: val_accuracy did not improve from 0.69718
# Epoch 35/100
# 12354/12354 [==============================] - 9s 692us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00035: val_accuracy did not improve from 0.69718
# Epoch 36/100
# 12354/12354 [==============================] - 9s 695us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6314 - val_accuracy: 0.6764
#
# Epoch 00036: val_accuracy did not improve from 0.69718
# Epoch 37/100
# 12354/12354 [==============================] - 9s 689us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6299 - val_accuracy: 0.6764
#
# Epoch 00037: val_accuracy did not improve from 0.69718
# Epoch 38/100
# 12354/12354 [==============================] - 8s 683us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00038: val_accuracy did not improve from 0.69718
# Epoch 39/100
# 12354/12354 [==============================] - 9s 699us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00039: val_accuracy did not improve from 0.69718
# Epoch 40/100
# 12354/12354 [==============================] - 9s 695us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
# Epoch 00040: val_accuracy did not improve from 0.69718
# Epoch 41/100
# 12354/12354 [==============================] - 9s 689us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6301 - val_accuracy: 0.6764
#
# Epoch 00041: val_accuracy did not improve from 0.69718
# Epoch 42/100
# 12354/12354 [==============================] - 9s 719us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00042: val_accuracy did not improve from 0.69718
# Epoch 43/100
# 12354/12354 [==============================] - 9s 708us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6302 - val_accuracy: 0.6764
#
# Epoch 00043: val_accuracy did not improve from 0.69718
# Epoch 44/100
# 12354/12354 [==============================] - 9s 692us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00044: val_accuracy did not improve from 0.69718
# Epoch 45/100
# 12354/12354 [==============================] - 9s 695us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00045: val_accuracy did not improve from 0.69718
# Epoch 46/100
# 12354/12354 [==============================] - 9s 695us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00046: val_accuracy did not improve from 0.69718
# Epoch 47/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6253 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00047: val_accuracy did not improve from 0.69718
# Epoch 48/100
# 12354/12354 [==============================] - 9s 699us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00048: val_accuracy did not improve from 0.69718
# Epoch 49/100
# 12354/12354 [==============================] - 9s 694us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00049: val_accuracy did not improve from 0.69718
# Epoch 50/100
# 12354/12354 [==============================] - 9s 688us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6303 - val_accuracy: 0.6764
#
# Epoch 00050: val_accuracy did not improve from 0.69718
# Epoch 51/100
# 12354/12354 [==============================] - 8s 684us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00051: val_accuracy did not improve from 0.69718
# Epoch 52/100
# 12354/12354 [==============================] - 9s 695us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6303 - val_accuracy: 0.6764
#
# Epoch 00052: val_accuracy did not improve from 0.69718
# Epoch 53/100
# 12354/12354 [==============================] - 9s 697us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00053: val_accuracy did not improve from 0.69718
# Epoch 54/100
# 12354/12354 [==============================] - 9s 698us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00054: val_accuracy did not improve from 0.69718
# Epoch 55/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00055: val_accuracy did not improve from 0.69718
# Epoch 56/100
# 12354/12354 [==============================] - 9s 705us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00056: val_accuracy did not improve from 0.69718
# Epoch 57/100
# 12354/12354 [==============================] - 9s 690us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00057: val_accuracy did not improve from 0.69718
# Epoch 58/100
# 12354/12354 [==============================] - 9s 709us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00058: val_accuracy did not improve from 0.69718
# Epoch 59/100
# 12354/12354 [==============================] - 9s 689us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00059: val_accuracy did not improve from 0.69718
# Epoch 60/100
# 12354/12354 [==============================] - 9s 692us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00060: val_accuracy did not improve from 0.69718
# Epoch 61/100
# 12354/12354 [==============================] - 9s 692us/step - loss: 0.6257 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00061: val_accuracy did not improve from 0.69718
# Epoch 62/100
# 12354/12354 [==============================] - 9s 690us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6304 - val_accuracy: 0.6764
#
# Epoch 00062: val_accuracy did not improve from 0.69718
# Epoch 63/100
# 12354/12354 [==============================] - 9s 694us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00063: val_accuracy did not improve from 0.69718
# Epoch 64/100
# 12354/12354 [==============================] - 8s 687us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6305 - val_accuracy: 0.6764
#
# Epoch 00064: val_accuracy did not improve from 0.69718
# Epoch 65/100
# 12354/12354 [==============================] - 9s 697us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00065: val_accuracy did not improve from 0.69718
# Epoch 66/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00066: val_accuracy did not improve from 0.69718
# Epoch 67/100
# 12354/12354 [==============================] - 8s 687us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00067: val_accuracy did not improve from 0.69718
# Epoch 68/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00068: val_accuracy did not improve from 0.69718
# Epoch 69/100
# 12354/12354 [==============================] - 9s 695us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00069: val_accuracy did not improve from 0.69718
# Epoch 70/100
# 12354/12354 [==============================] - 9s 697us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00070: val_accuracy did not improve from 0.69718
# Epoch 71/100
# 12354/12354 [==============================] - 9s 699us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00071: val_accuracy did not improve from 0.69718
# Epoch 72/100
# 12354/12354 [==============================] - 9s 719us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6299 - val_accuracy: 0.6764
#
# Epoch 00072: val_accuracy did not improve from 0.69718
# Epoch 73/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00073: val_accuracy did not improve from 0.69718
# Epoch 74/100
# 12354/12354 [==============================] - 9s 713us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00074: val_accuracy did not improve from 0.69718
# Epoch 75/100
# 12354/12354 [==============================] - 9s 701us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00075: val_accuracy did not improve from 0.69718
# Epoch 76/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6301 - val_accuracy: 0.6764
#
# Epoch 00076: val_accuracy did not improve from 0.69718
# Epoch 77/100
# 12354/12354 [==============================] - 9s 708us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00077: val_accuracy did not improve from 0.69718
# Epoch 78/100
# 12354/12354 [==============================] - 9s 724us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00078: val_accuracy did not improve from 0.69718
# Epoch 79/100
# 12354/12354 [==============================] - 9s 692us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00079: val_accuracy did not improve from 0.69718
# Epoch 80/100
# 12354/12354 [==============================] - 9s 705us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
# Epoch 00080: val_accuracy did not improve from 0.69718
# Epoch 81/100
# 12354/12354 [==============================] - 8s 686us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00081: val_accuracy did not improve from 0.69718
# Epoch 82/100
# 12354/12354 [==============================] - 9s 697us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00082: val_accuracy did not improve from 0.69718
# Epoch 83/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00083: val_accuracy did not improve from 0.69718
# Epoch 84/100
# 12354/12354 [==============================] - 9s 693us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6304 - val_accuracy: 0.6764
#
# Epoch 00084: val_accuracy did not improve from 0.69718
# Epoch 85/100
# 12354/12354 [==============================] - 8s 685us/step - loss: 0.6256 - accuracy: 0.6821 - val_loss: 0.6299 - val_accuracy: 0.6764
#
# Epoch 00085: val_accuracy did not improve from 0.69718
# Epoch 86/100
# 12354/12354 [==============================] - 9s 689us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00086: val_accuracy did not improve from 0.69718
# Epoch 87/100
# 12354/12354 [==============================] - 9s 690us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00087: val_accuracy did not improve from 0.69718
# Epoch 88/100
# 12354/12354 [==============================] - 8s 686us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00088: val_accuracy did not improve from 0.69718
# Epoch 89/100
# 12354/12354 [==============================] - 9s 689us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00089: val_accuracy did not improve from 0.69718
# Epoch 90/100
# 12354/12354 [==============================] - 9s 695us/step - loss: 0.6253 - accuracy: 0.6821 - val_loss: 0.6303 - val_accuracy: 0.6764
#
# Epoch 00090: val_accuracy did not improve from 0.69718
# Epoch 91/100
# 12354/12354 [==============================] - 9s 691us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6302 - val_accuracy: 0.6764
#
# Epoch 00091: val_accuracy did not improve from 0.69718
# Epoch 92/100
# 12354/12354 [==============================] - 8s 688us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00092: val_accuracy did not improve from 0.69718
# Epoch 93/100
# 12354/12354 [==============================] - 8s 687us/step - loss: 0.6254 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00093: val_accuracy did not improve from 0.69718
# Epoch 94/100
# 12354/12354 [==============================] - 9s 690us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00094: val_accuracy did not improve from 0.69718
# Epoch 95/100
# 12354/12354 [==============================] - 9s 690us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6298 - val_accuracy: 0.6764
#
# Epoch 00095: val_accuracy did not improve from 0.69718
# Epoch 96/100
# 12354/12354 [==============================] - 8s 684us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00096: val_accuracy did not improve from 0.69718
# Epoch 97/100
# 12354/12354 [==============================] - 8s 686us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6296 - val_accuracy: 0.6764
#
# Epoch 00097: val_accuracy did not improve from 0.69718
# Epoch 98/100
# 12354/12354 [==============================] - 9s 690us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00098: val_accuracy did not improve from 0.69718
# Epoch 99/100
# 12354/12354 [==============================] - 8s 687us/step - loss: 0.6253 - accuracy: 0.6821 - val_loss: 0.6307 - val_accuracy: 0.6764
#
# Epoch 00099: val_accuracy did not improve from 0.69718
# Epoch 100/100
# 12354/12354 [==============================] - 8s 687us/step - loss: 0.6255 - accuracy: 0.6821 - val_loss: 0.6297 - val_accuracy: 0.6764
#
# Epoch 00100: val_accuracy did not improve from 0.69718

# %% [markdown]
# 테스트셋 정확도

# %%
results = model.evaluate(x_test, y_test)
print('Test accuracy: ', results[1])
# Out:
# 2746/2746 [==============================] - 1s 327us/step
# Test accuracy:  0.6769847273826599
