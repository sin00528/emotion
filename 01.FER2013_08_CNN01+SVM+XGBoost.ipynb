# %% [markdown]
# # 1. FER2013 CNN01+SVM+XGBoost 분류

# %%
import sys
import os
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import xgboost as xgb
import tensorflow as tf
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC

from sklearn.model_selection import train_test_split

import keras.backend.tensorflow_backend as K
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.models import Sequential, Model
from keras.layers import Dense, Activation, Flatten, Dropout, concatenate, Input, Conv2D, UpSampling2D, MaxPooling2D
from keras.optimizers import Adam, Adadelta
from keras.regularizers import l2
from keras.layers.advanced_activations import LeakyReLU
from keras.utils.np_utils import to_categorical
from keras.callbacks import ModelCheckpoint
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## 1.1. 학습에 사용될 하이퍼 패러미터 선언 및 Random Seed 설정

# %%
np.random.seed(201)

# %%
FER2013_DIR = "datasets/fer2013/prep/"
INPUT_TRAIN_DATA = 'fer2013_X.npy'
LABEL_TRAIN_DATA = 'fer2013_y.npy'

TEST_SPLIT = 0.2
RND_SEED = 0

# %%
input_data = np.load(open(FER2013_DIR + INPUT_TRAIN_DATA, 'rb'))
label_data = np.load(open(FER2013_DIR + LABEL_TRAIN_DATA, 'rb'))

# %%
input_shape = input_data[1].shape
print('Input Shape is :', input_shape)
# Out:
# Input Shape is : (48, 48, 1)

# %%
x_train, x_test, y_train, y_test = train_test_split(input_data,
                                                    label_data,
                                                    test_size=TEST_SPLIT,
                                                    random_state=RND_SEED)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train,
                                                  y_train,
                                                  test_size=TEST_SPLIT,
                                                  random_state=RND_SEED)

# %% [markdown]
# ## 1.2 CNN모델 정의

# %% [markdown]
# 모델 컴파일

# %%
def fire_incept(x, fire=16, intercept=64):
    x = Conv2D(fire, (5,5), strides=(2,2))(x)
    x = LeakyReLU(alpha=0.15)(x)
    
    left = Conv2D(intercept, (3,3), padding='same')(x)
    left = LeakyReLU(alpha=0.15)(left)
    
    right = Conv2D(intercept, (5,5), padding='same')(x)
    right = LeakyReLU(alpha=0.15)(right)
    
    x = concatenate([left, right], axis=3)
    return x

def fire_squeeze(x, fire=16, intercept=64):
    x = Conv2D(fire, (1,1))(x)
    x = LeakyReLU(alpha=0.15)(x)
    
    left = Conv2D(intercept, (1,1))(x)
    left = LeakyReLU(alpha=0.15)(left)
    
    right = Conv2D(intercept, (3,3), padding='same')(x)
    right = LeakyReLU(alpha=0.15)(right)
    
    x = concatenate([left, right], axis=3)
    return x

# %%
image_input=Input(shape=input_shape)

x = fire_incept((image_input), fire=16, intercept=16)

x = fire_incept(x, fire=32, intercept=32)
x = fire_squeeze(x, fire=32, intercept=32)

x = fire_incept(x, fire=64, intercept=64)
x = fire_squeeze(x, fire=64, intercept=64)

x = Conv2D(64, (3,3))(x)
x = LeakyReLU(alpha=0.2)(x)

x = Flatten()(x)

x = Dense(512)(x)
x = LeakyReLU(alpha=0.1)(x)
x = Dropout(0.1)(x)

out = Dense(2, activation='softmax')(x)

# %%
model = Model(image_input, out)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 48, 48, 1)    0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 22, 22, 16)   416         input_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)       (None, 22, 22, 16)   0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 22, 22, 16)   2320        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 22, 22, 16)   6416        leaky_re_lu_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)       (None, 22, 22, 16)   0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)       (None, 22, 22, 16)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 22, 22, 32)   0           leaky_re_lu_2[0][0]
#                                                                  leaky_re_lu_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 9, 9, 32)     25632       concatenate_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)       (None, 9, 9, 32)     0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 9, 9, 32)     9248        leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 9, 9, 32)     25632       leaky_re_lu_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)       (None, 9, 9, 32)     0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)       (None, 9, 9, 32)     0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 9, 9, 64)     0           leaky_re_lu_5[0][0]
#                                                                  leaky_re_lu_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 9, 9, 32)     2080        concatenate_2[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)       (None, 9, 9, 32)     0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 9, 9, 32)     1056        leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 9, 9, 32)     9248        leaky_re_lu_7[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)       (None, 9, 9, 32)     0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)       (None, 9, 9, 32)     0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 9, 9, 64)     0           leaky_re_lu_8[0][0]
#                                                                  leaky_re_lu_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 3, 3, 64)     102464      concatenate_3[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_10 (LeakyReLU)      (None, 3, 3, 64)     0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 3, 3, 64)     36928       leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 3, 3, 64)     102464      leaky_re_lu_10[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_11 (LeakyReLU)      (None, 3, 3, 64)     0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_12 (LeakyReLU)      (None, 3, 3, 64)     0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 3, 3, 128)    0           leaky_re_lu_11[0][0]
#                                                                  leaky_re_lu_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 3, 3, 64)     8256        concatenate_4[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_13 (LeakyReLU)      (None, 3, 3, 64)     0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 3, 3, 64)     4160        leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 3, 3, 64)     36928       leaky_re_lu_13[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)      (None, 3, 3, 64)     0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)      (None, 3, 3, 64)     0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 3, 3, 128)    0           leaky_re_lu_14[0][0]
#                                                                  leaky_re_lu_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 1, 1, 64)     73792       concatenate_5[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)      (None, 1, 1, 64)     0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 64)           0           leaky_re_lu_16[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 512)          33280       flatten_1[0][0]
# __________________________________________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)      (None, 512)          0           dense_1[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 512)          0           leaky_re_lu_17[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 2)            1026        dropout_1[0][0]
# ==================================================================================================
# Total params: 481,346
# Trainable params: 481,346
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# 모델 플롯 생성

# %%
tf.keras.utils.plot_model(model, to_file='cnn/plot/fer2013/model.png')

# %%
model.compile(optimizer = Adam(lr=.00025) , loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
MODEL_PATH = 'cnn/weight/fer2013/model_weights.h5f'

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=3, verbose=1, factor=0.5, min_lr=0.0001)
check_point = ModelCheckpoint(filepath=MODEL_PATH, monitor='val_accuracy', verbose=1, save_best_only=True)

# %% [markdown]
# ## 1.3 CNN 모델 훈련

# %%
batch_size = 32
epochs = 40

# %%
# Training
with K.tf_ops.device('/device:GPU:0'):
    history = model.fit(x_train, y_train, epochs = epochs, batch_size = batch_size,
                        validation_data = (x_val, y_val), callbacks=[learning_rate_reduction, check_point])
# Out:
# Train on 9641 samples, validate on 2411 samples
# Epoch 1/40
# 9641/9641 [==============================] - 6s 627us/step - loss: 0.5873 - accuracy: 0.6814 - val_loss: 0.5297 - val_accuracy: 0.7391
#
# Epoch 00001: val_accuracy improved from -inf to 0.73911, saving model to cnn/weight/fer2013/model_weights.h5f
# Epoch 2/40
# 9641/9641 [==============================] - 3s 273us/step - loss: 0.4836 - accuracy: 0.7630 - val_loss: 0.4646 - val_accuracy: 0.7793
#
# Epoch 00002: val_accuracy improved from 0.73911 to 0.77934, saving model to cnn/weight/fer2013/model_weights.h5f
# Epoch 3/40
# 9641/9641 [==============================] - 2s 246us/step - loss: 0.4212 - accuracy: 0.7978 - val_loss: 0.4524 - val_accuracy: 0.7922
#
# Epoch 00003: val_accuracy improved from 0.77934 to 0.79220, saving model to cnn/weight/fer2013/model_weights.h5f
# Epoch 4/40
# 9641/9641 [==============================] - 3s 268us/step - loss: 0.3732 - accuracy: 0.8267 - val_loss: 0.3927 - val_accuracy: 0.8221
#
# Epoch 00004: val_accuracy improved from 0.79220 to 0.82207, saving model to cnn/weight/fer2013/model_weights.h5f
# Epoch 5/40
# 9641/9641 [==============================] - 3s 284us/step - loss: 0.3115 - accuracy: 0.8616 - val_loss: 0.4268 - val_accuracy: 0.8100
#
# Epoch 00005: val_accuracy did not improve from 0.82207
# Epoch 6/40
# 9641/9641 [==============================] - 3s 267us/step - loss: 0.2482 - accuracy: 0.8924 - val_loss: 0.4499 - val_accuracy: 0.8030
#
# Epoch 00006: val_accuracy did not improve from 0.82207
# Epoch 7/40
# 9641/9641 [==============================] - 3s 280us/step - loss: 0.1871 - accuracy: 0.9211 - val_loss: 0.5003 - val_accuracy: 0.8080
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 00007: val_accuracy did not improve from 0.82207
# Epoch 8/40
# 9641/9641 [==============================] - 3s 267us/step - loss: 0.0812 - accuracy: 0.9714 - val_loss: 0.6807 - val_accuracy: 0.8080
#
# Epoch 00008: val_accuracy did not improve from 0.82207
# Epoch 9/40
# 9641/9641 [==============================] - 3s 317us/step - loss: 0.0439 - accuracy: 0.9843 - val_loss: 0.7975 - val_accuracy: 0.8134
#
# Epoch 00009: val_accuracy did not improve from 0.82207
# Epoch 10/40
# 9641/9641 [==============================] - 3s 293us/step - loss: 0.0311 - accuracy: 0.9893 - val_loss: 0.8697 - val_accuracy: 0.8051
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0001.
#
# Epoch 00010: val_accuracy did not improve from 0.82207
# Epoch 11/40
# 9641/9641 [==============================] - 2s 232us/step - loss: 0.0216 - accuracy: 0.9920 - val_loss: 1.0319 - val_accuracy: 0.8059
#
# Epoch 00011: val_accuracy did not improve from 0.82207
# Epoch 12/40
# 9641/9641 [==============================] - 4s 373us/step - loss: 0.0091 - accuracy: 0.9972 - val_loss: 1.1373 - val_accuracy: 0.8146
#
# Epoch 00012: val_accuracy did not improve from 0.82207
# Epoch 13/40
# 9641/9641 [==============================] - 3s 329us/step - loss: 0.0136 - accuracy: 0.9955 - val_loss: 1.2485 - val_accuracy: 0.8022
#
# Epoch 00013: val_accuracy did not improve from 0.82207
# Epoch 14/40
# 9641/9641 [==============================] - 3s 328us/step - loss: 0.0063 - accuracy: 0.9981 - val_loss: 1.3384 - val_accuracy: 0.8038
#
# Epoch 00014: val_accuracy did not improve from 0.82207
# Epoch 15/40
# 9641/9641 [==============================] - 3s 303us/step - loss: 0.0162 - accuracy: 0.9937 - val_loss: 1.2137 - val_accuracy: 0.8046
#
# Epoch 00015: val_accuracy did not improve from 0.82207
# Epoch 16/40
# 9641/9641 [==============================] - 3s 318us/step - loss: 0.0116 - accuracy: 0.9959 - val_loss: 1.2834 - val_accuracy: 0.8075
#
# Epoch 00016: val_accuracy did not improve from 0.82207
# Epoch 17/40
# 9641/9641 [==============================] - 3s 315us/step - loss: 0.0111 - accuracy: 0.9964 - val_loss: 1.1953 - val_accuracy: 0.8121
#
# Epoch 00017: val_accuracy did not improve from 0.82207
# Epoch 18/40
# 9641/9641 [==============================] - 4s 462us/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 1.3253 - val_accuracy: 0.8138
#
# Epoch 00018: val_accuracy did not improve from 0.82207
# Epoch 19/40
# 9641/9641 [==============================] - 3s 272us/step - loss: 0.0026 - accuracy: 0.9993 - val_loss: 1.3961 - val_accuracy: 0.8146
#
# Epoch 00019: val_accuracy did not improve from 0.82207
# Epoch 20/40
# 9641/9641 [==============================] - 3s 319us/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 1.4746 - val_accuracy: 0.8063
#
# Epoch 00020: val_accuracy did not improve from 0.82207
# Epoch 21/40
# 9641/9641 [==============================] - 3s 341us/step - loss: 0.0190 - accuracy: 0.9941 - val_loss: 1.1086 - val_accuracy: 0.8071
#
# Epoch 00021: val_accuracy did not improve from 0.82207
# Epoch 22/40
# 9641/9641 [==============================] - 4s 462us/step - loss: 0.0122 - accuracy: 0.9955 - val_loss: 1.2154 - val_accuracy: 0.8150
#
# Epoch 00022: val_accuracy did not improve from 0.82207
# Epoch 23/40
# 9641/9641 [==============================] - 2s 247us/step - loss: 0.0098 - accuracy: 0.9966 - val_loss: 1.3732 - val_accuracy: 0.8055
#
# Epoch 00023: val_accuracy did not improve from 0.82207
# Epoch 24/40
# 9641/9641 [==============================] - 3s 261us/step - loss: 0.0091 - accuracy: 0.9970 - val_loss: 1.3549 - val_accuracy: 0.8109
#
# Epoch 00024: val_accuracy did not improve from 0.82207
# Epoch 25/40
# 9641/9641 [==============================] - 2s 254us/step - loss: 0.0034 - accuracy: 0.9987 - val_loss: 1.4244 - val_accuracy: 0.8051
#
# Epoch 00025: val_accuracy did not improve from 0.82207
# Epoch 26/40
# 9641/9641 [==============================] - 5s 506us/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 1.3974 - val_accuracy: 0.8075
#
# Epoch 00026: val_accuracy did not improve from 0.82207
# Epoch 27/40
# 9641/9641 [==============================] - 3s 284us/step - loss: 0.0132 - accuracy: 0.9947 - val_loss: 1.1267 - val_accuracy: 0.8092
#
# Epoch 00027: val_accuracy did not improve from 0.82207
# Epoch 28/40
# 9641/9641 [==============================] - 2s 257us/step - loss: 0.0117 - accuracy: 0.9956 - val_loss: 1.1969 - val_accuracy: 0.8063
#
# Epoch 00028: val_accuracy did not improve from 0.82207
# Epoch 29/40
# 9641/9641 [==============================] - 3s 332us/step - loss: 0.0033 - accuracy: 0.9987 - val_loss: 1.2957 - val_accuracy: 0.8146
#
# Epoch 00029: val_accuracy did not improve from 0.82207
# Epoch 30/40
# 9641/9641 [==============================] - 3s 285us/step - loss: 0.0012 - accuracy: 0.9996 - val_loss: 1.3565 - val_accuracy: 0.8179
#
# Epoch 00030: val_accuracy did not improve from 0.82207
# Epoch 31/40
# 9641/9641 [==============================] - 2s 232us/step - loss: 0.0035 - accuracy: 0.9991 - val_loss: 1.3653 - val_accuracy: 0.8117
#
# Epoch 00031: val_accuracy did not improve from 0.82207
# Epoch 32/40
# 9641/9641 [==============================] - 3s 362us/step - loss: 0.0147 - accuracy: 0.9951 - val_loss: 1.2354 - val_accuracy: 0.8096
#
# Epoch 00032: val_accuracy did not improve from 0.82207
# Epoch 33/40
# 9641/9641 [==============================] - 3s 304us/step - loss: 0.0111 - accuracy: 0.9959 - val_loss: 1.1747 - val_accuracy: 0.8109
#
# Epoch 00033: val_accuracy did not improve from 0.82207
# Epoch 34/40
# 9641/9641 [==============================] - 4s 382us/step - loss: 0.0076 - accuracy: 0.9973 - val_loss: 1.2450 - val_accuracy: 0.8187
#
# Epoch 00034: val_accuracy did not improve from 0.82207
# Epoch 35/40
# 9641/9641 [==============================] - 4s 404us/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 1.2807 - val_accuracy: 0.8163
#
# Epoch 00035: val_accuracy did not improve from 0.82207
# Epoch 36/40
# 9641/9641 [==============================] - 2s 228us/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 1.3777 - val_accuracy: 0.8142
#
# Epoch 00036: val_accuracy did not improve from 0.82207
# Epoch 37/40
# 9641/9641 [==============================] - 3s 274us/step - loss: 0.0015 - accuracy: 0.9996 - val_loss: 1.4725 - val_accuracy: 0.8121
#
# Epoch 00037: val_accuracy did not improve from 0.82207
# Epoch 38/40
# 9641/9641 [==============================] - 3s 277us/step - loss: 0.0105 - accuracy: 0.9963 - val_loss: 1.2677 - val_accuracy: 0.8146
#
# Epoch 00038: val_accuracy did not improve from 0.82207
# Epoch 39/40
# 9641/9641 [==============================] - 3s 296us/step - loss: 0.0140 - accuracy: 0.9952 - val_loss: 1.1967 - val_accuracy: 0.8096
#
# Epoch 00039: val_accuracy did not improve from 0.82207
# Epoch 40/40
# 9641/9641 [==============================] - 3s 309us/step - loss: 0.0070 - accuracy: 0.9977 - val_loss: 1.1819 - val_accuracy: 0.8100
#
# Epoch 00040: val_accuracy did not improve from 0.82207

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Training for ' +str(epochs)+ ' epochs')
plt.legend(['Training accuracy', 'Validation accuracy'], loc='lower right')
plt.show()

# %% [markdown]
# 검증셋 정확도

# %%
model.load_weights(MODEL_PATH)
results = model.evaluate(x_val, y_val)
print('Test accuracy: ', results[1])
# Out:
# 2411/2411 [==============================] - 0s 74us/step
# Test accuracy:  0.822065532207489

# %% [markdown]
# ## 1.3 SVM 적용

# %% [markdown]
# 마지막 레이어에서 특징추출

# %%
model_feat = Model(inputs=model.input,outputs=model.get_layer('dense_1').output)

feat_train = model_feat.predict(x_train)
print(feat_train.shape)

feat_val = model_feat.predict(x_val)
print(feat_val.shape)

feat_test = model_feat.predict(x_test)
print(feat_test.shape)
# Out:
# (9641, 512)
# (2411, 512)
# (3014, 512)

# %% [markdown]
# SVM에 적용

# %%
svm = SVC(kernel='rbf')

svm.fit(feat_train, np.argmax(y_train,axis=1))

print('fitting done !!!')
# Out:
# fitting done !!!

# %% [markdown]
# 훈련셋 정확도

# %%
svm.score(feat_train, np.argmax(y_train,axis=1))
# Out:
# 0.8822736230681465

# %% [markdown]
# 검증셋 정확도

# %%
svm.score(feat_val, np.argmax(y_val,axis=1))
# Out:
# 0.8224802986312734

# %% [markdown]
# SVM의 Prediction 저장

# %%
prediction = svm.predict(feat_test)

# %% [markdown]
# ## 1.4 XGBoost 적용

# %%
xb = xgb.XGBClassifier()

xb.fit(feat_train, np.argmax(y_train,axis=1))
print('fitting done !!!')
# Out:
# fitting done !!!

# %% [markdown]
# 검증셋 정확도

# %%
xb.score(feat_val, np.argmax(y_val,axis=1))
# Out:
# 0.8262131895479055

# %% [markdown]
# XGBoost의 Prediction 저장

# %%
prediction = xb.predict(feat_test)

# %% [markdown]
# 최종 정확도 측정

# %%
xb.score(feat_test, np.argmax(y_test,axis=1))
# Out:
# 0.8148639681486397
